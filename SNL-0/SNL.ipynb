# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
characters = pd.read_csv("characters.csv")
characters.head(10)
# Out:
#                 aid  charid             name
# 0       Dana Carvey     217      Church Lady
# 1  Victoria Jackson     228      Jenny Baker
# 2        Jon Lovitz     196   Tommy Flanagan
# 3         Nora Dunn     224      Liz Sweeney
# 4         Jan Hooks     223    Candy Sweeney
# 5      Marc Shaiman     225  Skip St. Thomas
# 6    Kenan Thompson     972           Willie
# 7      Will Ferrell     521       Jacob Silj
# 8     Pete Davidson    1010             Chad
# 9    Kenan Thompson     977           Gerard

# %%
characters.aid.value_counts()
# Out:
# Kenan Thompson           40
# Fred Armisen             35
# Kristen Wiig             30
# Will Ferrell             27
# Bobby Moynihan           26
# Bill Hader               23
# Horatio Sanz             22
# Phil Hartman             21
# Will Forte               19
# Vanessa Bayer            19
# Dan Aykroyd              19
# Jason Sudeikis           18
# Gilda Radner             18
# Andy Samberg             18
# Rachel Dratch            18
# Cheri Oteri              17
# Jon Lovitz               17
# Ana Gasteyer             17
# Maya Rudolph             16
# Kate McKinnon            16
# Mike Myers               16
# Cecily Strong            16
# Taran Killam             15
# Adam Sandler             15
# Molly Shannon            15
# Kevin Nealon             15
# Dana Carvey              15
# Tim Meadows              14
# Bill Murray              14
# Chris Parnell            14
#                          ..
# Charlton Heston           1
# Tom Schiller              1
# ...

# %%
impressions = pd.read_csv("impressions.csv")
impressions.head()
# Out:
#             aid  impid               name
# 0   Dana Carvey    614        Robin Leach
# 1     Jan Hooks    624  Tammy Faye Bakker
# 2    Jon Lovitz    647        Judd Nelson
# 3   Dana Carvey    649     George F. Will
# 4  Phil Hartman    648     David Brinkley

# %%
impressions.aid.value_counts()
# Out:
# Kenan Thompson        125
# Darrell Hammond       107
# Fred Armisen           99
# Taran Killam           95
# Bill Hader             81
# Jason Sudeikis         78
# Phil Hartman           77
# Jimmy Fallon           73
# Kate McKinnon          69
# Bobby Moynihan         68
# Will Ferrell           67
# Chris Kattan           67
# Tim Meadows            64
# Kristen Wiig           64
# Amy Poehler            58
# Jay Pharoah            57
# Dana Carvey            56
# Maya Rudolph           56
# Andy Samberg           54
# Ana Gasteyer           51
# Rachel Dratch          48
# Chris Parnell          47
# Horatio Sanz           47
# Jan Hooks              47
# Cecily Strong          47
# Joe Piscopo            47
# Kevin Nealon           46
# Tracy Morgan           41
# Will Forte             40
# Mike Myers             39
#                      ...
# Bob Zmuda               1
# Dakota Johnson          1
# Bronson Pinchot         1
# Billy Martin            1
# ...

# %%
impressions.aid.value_counts().head(10).sort_values(ascending=True).plot(x='name', y='aid', kind='barh')

# %%
impressions.name.value_counts()
# Out:
# Matthew McConaughey         10
# Hillary Clinton              9
# Martha Stewart               8
# Saddam Hussein               7
# Christina Aguilera           7
# Britney Spears               7
# Madonna                      7
# Michael Jackson              7
# Ronald Reagan                7
# Liza Minnelli                7
# Marilyn Monroe               6
# Joan Rivers                  6
# Michael Gelman               6
# Rod Serling                  6
# Adolf Hitler                 6
# Prince Charles               6
# Diana Ross                   6
# Woody Allen                  6
# Wolf Blitzer                 6
# Yasser Arafat                6
# Newt Gingrich                5
# Colin Powell                 5
# Queen Elizabeth              5
# Patti LaBelle                5
# George W. Bush               5
# Nancy Reagan                 5
# Mick Jagger                  5
# Barbra Streisand             5
# Elizabeth Taylor             5
# Elvis Presley                5
# ...

# %%
impressions.name.value_counts().head(10).sort_values(ascending=True).plot(kind = 'barh')

# %%
# sketches = pd.read_csv("sketches.csv")
# sketches.head()

# %%
tenure = pd.read_csv("tenure.csv")
tenure.head(20)
# Out:
#                  aid  n_episodes  eps_present  n_seasons
# 0        Dana Carvey         125          123          7
# 1       Phil Hartman         153          153          8
# 2         Jon Lovitz          91           91          5
# 3   Victoria Jackson         113          113          6
# 4          Jan Hooks          93           93          5
# 5      Dennis Miller         111          111          6
# 6   A. Whitney Brown         101           56          6
# 7          Nora Dunn          91           89          5
# 8       Kevin Nealon         173          172          9
# 9          Tom Davis          56           48          3
# 10      Beck Bennett          97           97          5
# 11     Heidi Gardner          13           13          1
# 12       Alex Moffat          34           32          2
# 13        Chris Redd          13           13          1
# 14     Cecily Strong         118          118          6
# ...

# %%
tenure = tenure.drop(columns='n_episodes')

# %%
tenure.sort_values(by=['eps_present', 'n_seasons'], ascending=False).head(20)
# Out:
#                 aid  eps_present  n_seasons
# 17   Kenan Thompson          295         15
# 26  Darrell Hammond          267         14
# 61      Seth Meyers          251         13
# 33     Fred Armisen          219         11
# 45   Bobby Moynihan          192          9
# 82      Tim Meadows          181         10
# 8      Kevin Nealon          172          9
# 34   Jason Sudeikis          162          9
# 59       Bill Hader          159          8
# 1      Phil Hartman          153          8
# 48       Will Forte          153          8
# 74     Horatio Sanz          151          8
# 43    Vanessa Bayer          147          7
# 69    Chris Parnell          145          8
# 71     Chris Kattan          142          8
# 56      Amy Poehler          139          8
# 25     Andy Samberg          138          7
# 30     Will Ferrell          136          7
# 47     Kristen Wiig          135          7
# 18    Rachel Dratch          133          7

# %%
tenure.sort_values(by=['eps_present'], ascending=False).head(10).plot(x='aid', y=['eps_present', 'n_seasons'], kind='bar')

# %%
tenure.sort_values(by=['eps_present'], ascending=False).head(10).plot(x='aid', y='n_seasons', kind='barh')

# %%
ax = tenure.sort_values(by='eps_present').tail(20) \
    .plot(x='aid', y='eps_present', kind='barh', width=0.8, legend=None)

plt.box(False)
plt.tight_layout()
plt.savefig("SNLcast.pdf")

# %%
women = pd.read_csv("women.csv")
women.head()
# Out:
#                 aid  n_episodes  eps_present  n_seasons
# 0  Victoria Jackson         113          113          6
# 1         Jan Hooks          93           93          5
# 2  A. Whitney Brown         101           56          6
# 3         Nora Dunn          91           89          5
# 4     Heidi Gardner          13           13          1

# %%
ax = women.sort_values(by='eps_present').tail(10) \
    .plot(x='aid', y='eps_present', kind='barh', width=0.8,legend=None)

plt.box(False)
plt.tight_layout()
plt.savefig("SNLwomen.pdf")

# %%
# e=sns.factorplot(x="n_seasons", y="eps_present",col="aid", data=tenure, kind="swarm")
sns.lmplot('aid', 'eps_present', data=tenure, hue='n_seasons', fit_reg=False)

# %%
# sns.lmplot('aid', 'eps_present', data=tenure, hue='n_seasons', fit_reg=False, col="n_seasons")

# %%
sns.pairplot(tenure, diag_kind="kde")

# %%
df3 = tenure[['aid', 'eps_present']]
df3.head()
# Out:
#                 aid  eps_present
# 0       Dana Carvey          123
# 1      Phil Hartman          153
# 2        Jon Lovitz           91
# 3  Victoria Jackson          113
# 4         Jan Hooks           93

# %%
# df3.sort_values(by=['eps_present'], ascending=False)

# %%
colors = ['lightcoral', 'indianred', 'firebrick', 'maroon']
tenure.eps_present.sort_values(ascending=False).head(10).plot(kind="bar", width=0.9, color=colors)

# %%
hosts = pd.read_csv("hosts.csv")
hosts.head()
# Out:
#                 aid      epid
# 0     Dennis Hopper  19870523
# 1   Natalie Portman  20180203
# 2      Will Ferrell  20180127
# 3  Jessica Chastain  20180120
# 4      Sam Rockwell  20180113

# %%
hosts.aid.value_counts().head()
# Out:
# Alec Baldwin    17
# Steve Martin    15
# John Goodman    13
# Buck Henry      10
# Tom Hanks        9
# Name: aid, dtype: int64

# %%
sns.swarmplot(x = "aid", y = "eps_present", data = tenure)
plt.show()

# %%
colors = ['lightcoral', 'indianred', 'firebrick', 'maroon']
impressions.name.value_counts().head(20).plot(kind="bar", width=0.9, color=colors)

# %%
# sns.catplot(x="n_seasons",y="aid",data=tenure, height=10, s=10)


# plt.box(False)
# plt.tight_layout()
# # plt.savefig("SNLtest.pdf")

sns.swarmplot(x = "n_seasons", y = "aid", data = tenure)
plt.show()

# %%
tenure2 = tenure.sort_values(by='n_seasons', ascending=False).head(50)

# %%
sns.catplot(x="n_seasons",y="aid",data=tenure2, height=10, s=10)
# plt.savefig("SNLtest.pdf")

# %%
# sns.catplot(x="eps_present",y="aid",data=tenure2, height=10, s=10)


with sns.axes_style('white'):
    g = sns.factorplot("aid", data=tenure2, aspect=4.0, kind='count',
                       hue='eps_present', order=range(50, 300))
    g.set_ylabels('Number of Planets Discovered')
# Out:
# /Users/mara/.pyenv/versions/3.6.5/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Futura'

# set the style of the axes and the text color
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.4
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'

# create some fake data

imp = impressions.name.value_counts().head(10).sort_values(ascending=True)



# we first need a numeric placeholder for the y axis
my_range=list(range(1,len(imp.index)+1))

fig, ax = plt.subplots(figsize=(8,3.5))

# create for each expense type an horizontal line that starts at x = 0 with the length 
# represented by the specific expense percentage value.
plt.hlines(y=my_range, xmin=0, xmax=imp, color='#FFB6C1', alpha=0.5, linewidth=7)

# create for each expense type a dot at the level of the expense percentage value
plt.plot(imp, my_range, "o", markersize=8, color='#8B636C', alpha=0.9)

# set labels
ax.set_xlabel('')
ax.set_ylabel('')

# set axis
ax.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(my_range, imp.index)

# add an horizonal label for the y axis 


# change the style of the axis spines
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)

# set the spines position
ax.spines['bottom'].set_position(('axes', -0.04))
ax.spines['left'].set_position(('axes', 0.030))


plt.tight_layout()
plt.savefig("SNLimpr.pdf")

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Futura'

# set the style of the axes and the text color
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.7
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'


wom = characters.aid.value_counts().head(10).sort_values(ascending=True)

# we first need a numeric placeholder for the y axis
my_range=list(range(1,len(wom.index)+1))

fig, ax = plt.subplots(figsize=(8,3.5))

# create for each expense type an horizontal line that starts at x = 0 with the length 
# represented by the specific expense percentage value.
plt.hlines(y=my_range, xmin=0, xmax=wom, color='#00FA9A', alpha=0.5, linewidth=7)

# create for each expense type a dot at the level of the expense percentage value
plt.plot(wom, my_range, "o", markersize=8, color='#191970', alpha=0.9)

# set labels
ax.set_xlabel('')
ax.set_ylabel('')

# set axis
ax.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(my_range, wom.index)

# add an horizonal label for the y axis 


# change the style of the axis spines
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)

# set the spines position
ax.spines['bottom'].set_position(('axes', -0.04))
ax.spines['left'].set_position(('axes', 0.030))


plt.tight_layout()
plt.savefig("SNLchar.pdf")
