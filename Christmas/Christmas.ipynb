# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
christmas = pd.read_csv("Holiday_Songs.csv", encoding='latin-1')
christmas.head()
# Out:
#    Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 0           1  00IqwkT0PZhJ86PJajRCqk         0.195   0.348  A#   -10.106
# 1           2  01h424WG38dgY34vkI3Yd0         0.225   0.248   A   -15.871
# 2           3  08BhfyKUXxZrnyHrDavNHP         0.444   0.288  F#   -11.793
# 3           4  095XSaT8I2uI6Uldj2QrSl         0.687   0.496   A    -4.708
# 4           5  09b2gJR45Pyip2rx9CnXW1         0.477   0.841  F#    -5.172
#
#     mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 0  major       0.0332      0.820000          0.000000  ...  166.824
# 1  major       0.0337      0.912000          0.000143  ...   96.013
# 2  major       0.0326      0.911000          0.000007  ...  108.043
# 3  major       0.0339      0.434000          0.001440  ...   97.575
# 4  major       0.0358      0.000165          0.097100  ...  119.954
#
#    duration_ms  time_signature  key_mode      playlist_name  \
# ...

# %%
christmas.groupby(by='key').track_name.value_counts()
# Out:
# key  track_name
# A    8 Days of Christmas - Live                                                            1
#      A Perfect Christmas                                                                   1
#      Christmas Time Is Here - Vocal                                                        1
#      Counting Down to Christmas                                                            1
#      Happy Holiday / The Holiday Season                                                    1
#      I Saw Mommy Kissing Santa Claus                                                       1
#      I Wish It Could Be Christmas Everyday                                                 1
#      Jingle Bells                                                                          1
#      Merry Christmas Everyone                                                              1
#      Please Come Home for Christmas (feat. Smokey Robinson)                                1
# ...

# %%
christmas.groupby(by='key').mode.value_counts()
# Out:
# key  mode
# A    major    13
#      minor     3
# A#   major    11
#      minor     2
# B    major     7
#      minor     5
# C    major    22
#      minor     1
# C#   major     8
#      minor     1
# D    major    18
#      minor     1
# D#   major     8
# E    major     8
#      minor     1
# F    major    11
#      minor     3
# F#   major     7
#      minor     1
# G    major    19
#      minor     4
# G#   major    13
# Name: mode, dtype: int64

# %%
christmas.artist_name.value_counts().head()
# Out:
# Pentatonix       9
# Mariah Carey     6
# Elvis Presley    5
# Glee Cast        4
# Johnny Mathis    4
# Name: artist_name, dtype: int64

# %%
mariah = christmas[christmas['artist_name'].str.contains("Mariah", na=False)]

# %%
mariah.head()
# Out:
#     Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 6            7  0bYg9bo50gSsH3LtXe2SQn         0.335   0.625   G    -7.462
# 28          29  1f2lkuLldqRzvaFjJdjGXX         0.548   0.750   G    -7.984
# 35          36  1sFWEpf1aPYN576LS1aa4Y         0.170   0.362  A#   -11.673
# 37          38  1UebLMXVLAaAYoFXxegCIP         0.574   0.536   B    -7.291
# 60          61  3B7FO3kJ5kv3mX7yiaB7sT         0.362   0.505   E    -7.208
#
#      mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 6   major       0.0386         0.164          0.000000  ...  150.277
# 28  major       0.0398         0.209          0.000000  ...  143.109
# 35  major       0.0347         0.812          0.000000  ...  176.849
# 37  major       0.0323         0.311          0.000000  ...  118.199
# 60  major       0.0287         0.367          0.000006  ...  174.066
#
#     duration_ms  time_signature  key_mode      playlist_name  \
# ...

# %%
mariah = mariah.drop(columns=['track_uri', 'duration_ms', 'time_signature', 'playlist_name', 'playlist_img', 'album_img'])

# %%
mariah = mariah.drop(columns=['Unnamed: 0'])

# %%
mariah.head()
# Out:
#     danceability  energy key  loudness   mode  speechiness  acousticness  \
# 6          0.335   0.625   G    -7.462  major       0.0386         0.164
# 28         0.548   0.750   G    -7.984  major       0.0398         0.209
# 35         0.170   0.362  A#   -11.673  major       0.0347         0.812
# 37         0.574   0.536   B    -7.291  major       0.0323         0.311
# 60         0.362   0.505   E    -7.208  major       0.0287         0.367
#
#     instrumentalness  liveness  valence    tempo  key_mode  \
# 6           0.000000    0.0708    0.346  150.277   G major
# 28          0.000000    0.6980    0.419  143.109   G major
# 35          0.000000    0.1130    0.244  176.849  A# major
# 37          0.000000    0.2220    0.158  118.199   B major
# 60          0.000006    0.1540    0.192  174.066   E major
#
#                          track_name   artist_name       album_name
# 6   All I Want for Christmas Is You  Mariah Carey  Merry Christmas
# ...

# %%
# frank = frank.drop(columns=['Unnamed: 0', 'track_uri', 'duration_ms', 'time_signature', 'playlist_name', 'playlist_img', 'album_img'])

# %%
christmas[christmas['album_name'].str.contains("Hits", na=False)]
# Out:
#      Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 12           13  0iVVPWm4An3glF9QnCtM6e         0.529   0.723   F    -8.171
# 16           17  0oEBvSzYp0aS7Obdus1RGm         0.437   0.149   E   -18.128
# 20           21  0wDKteaNLe3xkaFtj6tH5h         0.668   0.843   C    -3.766
# 25           26  1CBg1D0t4FMLbco3posN7b         0.528   0.772   D    -7.013
# 29           30  1jc5ttAAqSlzN6XnInuUXm         0.758   0.711   A   -10.483
# 30           31  1kCMRwtyaXZRWhe2scYcBL         0.641   0.794   B    -4.906
# 39           40  1Zrt3eIobdcn7fJ0i1kjzW         0.520   0.271  G#    -9.806
# 41           42  23zpbHaZGv6yHaT88QlxTd         0.810   0.486   B   -13.442
# 44           45  2BuodTguympeX1JrAxZ8HN         0.155   0.287   F   -11.444
# 49           50  2PtKui5SZQf4KtAGiEJh7B         0.842   0.448  C#    -8.616
# 53           54  2v2EYR4AYGeup25aJHnwQc         0.300   0.306  G#   -11.865
# ...

# %%
pent = christmas[christmas['artist_name'].str.contains("Pentatonix", na=False)]
pent
# Out:
#      Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 64           65  3Fu6XvAT5yjzO8GMcvuM1s         0.719   0.504   B    -6.338
# 78           79  45nLgLtSiGCTtMFTsN6KeA         0.512   0.327   B    -8.027
# 79           80  47qXmZMqUZDXSnP5zONlwY         0.339   0.375  G#    -6.146
# 83           84  4jDXtVGAmIqu3Fc8ODzhmb         0.382   0.558   A    -6.399
# 84           85  4kZqBZ1cihUH8SoBZ3PBrd         0.711   0.602   G    -5.698
# 92           93  50YYe94G19kWVyhzdEXxki         0.683   0.560   E    -6.597
# 95           96  541mKUH89gViH3rPkSDecP         0.674   0.578  F#    -6.888
# 97           98  550rQQCGkrTzvp4SfpOPzx         0.321   0.377  A#    -7.385
# 156         157  7klqcDdyk3laSiOtxNrygB         0.254   0.318  A#    -6.992
#
#       mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 64   minor       0.0418        0.0601               0.0  ...   75.514
# ...

# %%
christmas.groupby(by='mode').track_name.value_counts()
# Out:
# mode   track_name
# major  Silver Bells                                                                    4
#        Sleigh Ride                                                                     4
#        Frosty the Snowman                                                              3
#        Have Yourself a Merry Little Christmas                                          3
#        White Christmas                                                                 3
#        A Marshmallow World                                                             2
#        All I Want for Christmas Is You                                                 2
#        Christmas (Baby Please Come Home)                                               2
#        Deck the Halls                                                                  2
#        Here Comes Santa Claus (Right Down Santa Claus Lane)                            2
# ...

# %%
silver = christmas[christmas['track_name'].str.contains("Silver", na=False)]
silver
# Out:
#      Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 0             1  00IqwkT0PZhJ86PJajRCqk         0.195   0.348  A#   -10.106
# 34           35  1qUNMljTcCUraMU82IU7aN         0.714   0.295   C   -12.652
# 53           54  2v2EYR4AYGeup25aJHnwQc         0.300   0.306  G#   -11.865
# 117         118  5XaF2L2Qi3S6i0cUQELTzB         0.450   0.165   A   -16.190
#
#       mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 0    major       0.0332         0.820          0.000000  ...  166.824
# 34   major       0.0347         0.834          0.000192  ...  131.566
# 53   major       0.0303         0.898          0.000000  ...   95.644
# 117  major       0.0336         0.690          0.002320  ...  102.708
#
#      duration_ms  time_signature  key_mode      playlist_name  \
# 0         213107               3  A# major  new_holiday_songs
# 34        195173               4   C major  new_holiday_songs
# ...

# %%
jingle = christmas[christmas['track_name'].str.contains("Jingle", na=False)]
jingle
# Out:
#      Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 17           18  0P6xicvZnvVwRCPv3307HM         0.610   0.661   G    -8.343
# 75           76  3y8Z2sOJrBt6yKEfsZG1NY         0.703   0.802   D    -4.408
# 143         144  77GcYr9JP6uvJM0kPa6Nzk         0.623   0.738  D#    -5.709
# 145         146  77pt4LRcJwf3iSF30dqEHr         0.557   0.726   A    -5.835
# 152         153  7Fzm10UeEDemvzlYroQguL         0.420   0.828  F#    -5.871
#
#       mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 17   major       0.1050         0.613          0.000269  ...   86.680
# 75   major       0.0286         0.680          0.000000  ...  128.847
# 143  major       0.0281         0.180          0.000000  ...  152.066
# 145  major       0.0508         0.444          0.000002  ...  140.131
# 152  major       0.1070         0.359          0.000000  ...  190.791
#
#      duration_ms  time_signature  key_mode      playlist_name  \
# ...

# %%
little = christmas[christmas['track_name'].str.contains("Yourself", na=False)]
little
# Out:
#      Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 89           90  4W8cUf5xe5g8si5OijFAqZ         0.687   0.643   B    -7.677
# 94           95  51u4r13PK8Bb2aKwuMkBtc         0.344   0.313   D   -11.614
# 123         124  67XXGKQrlBLCAg3gmHkamP         0.319   0.509  A#    -8.868
# 139         140  6ZDaRctHGLVCYY430vaAyT         0.205   0.188   G   -14.192
# 154         155  7j6JmuVQokjHpDqqTFjHax         0.244   0.274  G#   -10.433
#
#       mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 89   minor       0.0406        0.0222          0.000014  ...  147.969
# 94   major       0.0323        0.5600          0.000022  ...   82.555
# 123  major       0.0305        0.6420          0.000000  ...  144.550
# 139  major       0.0393        0.7740          0.000001  ...  172.142
# 154  major       0.0400        0.8710          0.000012  ...   68.534
#
#      duration_ms  time_signature  key_mode      playlist_name  \
# ...

# %%
last = christmas[christmas['track_name'].str.contains("Last", na=False)]
last
# Out:
#      Unnamed: 0               track_uri  danceability  energy key  loudness  \
# 10           11  0fUFpFczhuhJBz2Z28IL2x         0.630   0.757   F    -6.005
# 103         104  5eGf8gjsdP8NGkeHmpzDId         0.920   0.680   F    -3.900
# 144         145  77nF1t4qesuOJRd8lbIzNX         0.735   0.681   D    -6.195
#
#       mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 10   major       0.0254       0.00716           0.00000  ...  106.885
# 103  major       0.0554       0.30200           0.00000  ...  114.000
# 144  major       0.0282       0.21500           0.00001  ...  107.671
#
#      duration_ms  time_signature  key_mode      playlist_name  \
# 10        216627               4   F major  new_holiday_songs
# 103       192442               4   F major  new_holiday_songs
# 144       262760               4   D major  new_holiday_songs
#
#                                           playlist_img  \
# 10   https://mosaic.scdn.co/640/5f79f928a45b878579e...
# ...

# %%
minor = christmas[christmas['mode'].str.contains("minor", na=False)]

# %%
minor = minor.drop(columns=['Unnamed: 0', 'track_uri', 'duration_ms', 'time_signature', 'playlist_name', 'playlist_img', 'album_img', 'track_name', 'artist_name', 'album_name'])

# %%
minor.head()
# Out:
#     danceability  energy key  loudness   mode  speechiness  acousticness  \
# 8          0.547   0.110   D   -12.918  minor       0.0360       0.90600
# 12         0.529   0.723   F    -8.171  minor       0.0353       0.00109
# 38         0.675   0.877  C#    -4.508  minor       0.0373       0.00974
# 41         0.810   0.486   B   -13.442  minor       0.2650       0.00281
# 43         0.388   0.145   A   -19.697  minor       0.0318       0.97800
#
#     instrumentalness  liveness  valence    tempo  key_mode
# 8           0.005170    0.2410   0.3110  108.952   D minor
# 12          0.000028    0.2190   0.7080   79.989   F minor
# 38          0.000000    0.3330   0.6700  128.018  C# minor
# 41          0.000063    0.0949   0.6140   95.166   B minor
# 43          0.000007    0.0997   0.0911   75.474   A minor

# %%
minorheat = minor[['danceability', 'tempo', 'energy', 'acousticness']]
sns.heatmap(minorheat.corr(),annot=False,cmap="cool")

# %%
major = christmas[christmas['mode'].str.contains("major", na=False)]

# %%
major = major.drop(columns=['Unnamed: 0', 'track_uri', 'duration_ms', 'time_signature', 'playlist_name', 'playlist_img', 'album_img', 'track_name', 'artist_name', 'album_name'])

# %%
majorheat = major[['danceability', 'valence', 'energy', 'tempo','key']]
sns.heatmap(majorheat.corr(),annot=False,cmap="cool")

# %%
minorheat = minor[['danceability', 'valence', 'energy', 'tempo','key']]
sns.heatmap(minorheat.corr(),annot=False,cmap="cool")

# %%
sns.catplot(x="mode", y="energy", kind="swarm", data=christmas, hue='key', palette="Spectral", split=True)

# %%
sns.swarmplot(x="mode", y="energy", data=christmas, palette='Pastel1')

# %%
# p = sns.countplot(data=christmas, x = 'key', palette='Reds')

# %%
# from math import pi
# import numpy as np

# labels=np.array(['danceability', 'valence', 'loudness', 'key', 'energy'])
# stats=mariah.loc[:-1,labels].values

# angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# # close the plot
# stats=np.concatenate((stats,[stats[0]]))
# angles=np.concatenate((angles,[angles[0]]))

# fig=sns.plt.figure()
# ax = fig.add_subplot(111, polar=True)
# ax.plot(angles, stats, 'o-', linewidth=2)
# ax.fill(angles, stats, alpha=0.25)
# ax.set_thetagrids(angles * 180/np.pi, labels)
# ax.set_title([df.loc[386,"Name"]])
# ax.grid(True)

# %%
mariah2 = mariah.drop(columns=['artist_name', 'album_name', 'key_mode', 'track_name', 'instrumentalness', 'speechiness', 'key','mode'])
mariah2
# Out:
#     danceability  energy  loudness  acousticness  liveness  valence    tempo
# 6          0.335   0.625    -7.462        0.1640    0.0708    0.346  150.277
# 28         0.548   0.750    -7.984        0.2090    0.6980    0.419  143.109
# 35         0.170   0.362   -11.673        0.8120    0.1130    0.244  176.849
# 37         0.574   0.536    -7.291        0.3110    0.2220    0.158  118.199
# 60         0.362   0.505    -7.208        0.3670    0.1540    0.192  174.066
# 90         0.573   0.780    -7.467        0.0227    0.0927    0.718  127.132

# %%
ax = sns.kdeplot(silver['valence'], shade=True, color="b")
ax = sns.kdeplot(little['valence'], shade=True, color="r")
# ax = sns.kdeplot(jingle['energy'], shade=True, color="g")

plt.title("'Silver Bells' vs. 'Have Yourself A Merry Little Christmas'")
plt.box(False)
plt.tight_layout()

# %%
mariahheat = mariah[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
ax = sns.heatmap(mariahheat.corr(),annot=False,cmap="cool", linewidths=.3)
ax.set_title("Mariah Carey's Christmas Songs")
# Out:
# Text(0.5, 1, "Mariah Carey's Christmas Songs")

# %%
silverheat = silver[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
sns.heatmap(silverheat.corr(),annot=False,cmap="cool", linewidths=.3)

# %%
pentheat = pent[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
ax = sns.heatmap(pentheat.corr(),annot=False,cmap="cool", linewidths=.3)
ax.set_title("Pentatonix's Christmas Songs")
# Out:
# Text(0.5, 1, "Pentatonix's Christmas Songs")

# %%
christmasheat = christmas[['energy', 'danceability', 'valence', 'loudness', 'acousticness', 'tempo']]
sns.heatmap(christmasheat.corr(),annot=False,cmap="cool", linewidths=.3)

# %%
kelly = christmas[christmas['artist_name'].str.contains("Clarkson", na=False)]
kelly = kelly.drop(columns=['track_uri', 'duration_ms', 'time_signature', 'playlist_name', 'playlist_img', 'album_img'])

# %%
sinatra = christmas[christmas['artist_name'].str.contains("Sinatra", na=False)]
sinatra = sinatra.drop(columns=['track_uri', 'duration_ms', 'time_signature', 'playlist_name', 'playlist_img', 'album_img'])
sinatra
# Out:
#      Unnamed: 0  danceability  energy key  loudness   mode  speechiness  \
# 87           88         0.625   0.473   D    -5.242  major       0.0536
# 139         140         0.205   0.188   G   -14.192  major       0.0393
# 141         142         0.636   0.178   G   -12.179  minor       0.0656
#
#      acousticness  instrumentalness  liveness  valence    tempo key_mode  \
# 87          0.897          0.000000    0.3630    0.807  142.990  D major
# 139         0.774          0.000001    0.3760    0.291  172.142  G major
# 141         0.663          0.000000    0.0964    0.643  139.997  G minor
#
#                                             track_name    artist_name  \
# 87   Let It Snow! Let It Snow! Let It Snow! (with T...  Frank Sinatra
# 139             Have Yourself a Merry Little Christmas  Frank Sinatra
# 141                      Santa Claus Is Comin' to Town  Frank Sinatra
#
#                      album_name
# 87               Christmas Hits
# ...

# %%
kellyheat = kelly[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
ax = sns.heatmap(kellyheat.corr(),annot=False,cmap="cool", linewidths=.3)
ax.set_title("Kelly Clarkson's Christmas Songs")
# Out:
# Text(0.5, 1, "Kelly Clarkson's Christmas Songs")

# %%
sinatraheat = sinatra[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
ax = sns.heatmap(sinatraheat.corr(),annot=False,cmap="cool", linewidths=.3)
ax.set_title("Frank Sinatra's Christmas Songs")
# Out:
# Text(0.5, 1, "Frank Sinatra's Christmas Songs")
