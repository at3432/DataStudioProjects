# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
characters = pd.read_csv("characters.csv")
characters.head()
# Out:
#                 aid  charid            name
# 0       Dana Carvey     217     Church Lady
# 1  Victoria Jackson     228     Jenny Baker
# 2        Jon Lovitz     196  Tommy Flanagan
# 3         Nora Dunn     224     Liz Sweeney
# 4         Jan Hooks     223   Candy Sweeney

# %%
characters.aid.value_counts()
# Out:
# Kenan Thompson           40
# Fred Armisen             35
# Kristen Wiig             30
# Will Ferrell             27
# Bobby Moynihan           26
# Bill Hader               23
# Horatio Sanz             22
# Phil Hartman             21
# Vanessa Bayer            19
# Will Forte               19
# Dan Aykroyd              19
# Gilda Radner             18
# Rachel Dratch            18
# Jason Sudeikis           18
# Andy Samberg             18
# Cheri Oteri              17
# Jon Lovitz               17
# Ana Gasteyer             17
# Mike Myers               16
# Maya Rudolph             16
# Cecily Strong            16
# Kate McKinnon            16
# Molly Shannon            15
# Taran Killam             15
# Adam Sandler             15
# Dana Carvey              15
# Kevin Nealon             15
# Chris Parnell            14
# Tim Meadows              14
# Amy Poehler              14
#                          ..
# Paul Rudd                 1
# Jay Mohr                  1
# ...

# %%
impressions = pd.read_csv("impressions.csv")
impressions.head()
# Out:
#             aid  impid               name
# 0   Dana Carvey    614        Robin Leach
# 1     Jan Hooks    624  Tammy Faye Bakker
# 2    Jon Lovitz    647        Judd Nelson
# 3   Dana Carvey    649     George F. Will
# 4  Phil Hartman    648     David Brinkley

# %%
impressions.aid.value_counts()
# Out:
# Kenan Thompson       125
# Darrell Hammond      107
# Fred Armisen          99
# Taran Killam          95
# Bill Hader            81
# Jason Sudeikis        78
# Phil Hartman          77
# Jimmy Fallon          73
# Kate McKinnon         69
# Bobby Moynihan        68
# Will Ferrell          67
# Chris Kattan          67
# Kristen Wiig          64
# Tim Meadows           64
# Amy Poehler           58
# Jay Pharoah           57
# Dana Carvey           56
# Maya Rudolph          56
# Andy Samberg          54
# Ana Gasteyer          51
# Rachel Dratch         48
# Horatio Sanz          47
# Jan Hooks             47
# Joe Piscopo           47
# Chris Parnell         47
# Cecily Strong         47
# Kevin Nealon          46
# Tracy Morgan          41
# Will Forte            40
# Jon Lovitz            39
#                     ...
# Andrew Dice Clay       1
# Robert Carlock         1
# Peter Boyle            1
# Dwayne Johnson         1
# Sean Penn              1
# Kyle MacLachlan        1
# ...

# %%
impressions.name.value_counts()
# Out:
# Matthew McConaughey                 10
# Hillary Clinton                      9
# Martha Stewart                       8
# Christina Aguilera                   7
# Liza Minnelli                        7
# Michael Jackson                      7
# Ronald Reagan                        7
# Britney Spears                       7
# Madonna                              7
# Saddam Hussein                       7
# Diana Ross                           6
# Michael Gelman                       6
# Yasser Arafat                        6
# Prince Charles                       6
# Wolf Blitzer                         6
# Woody Allen                          6
# Rod Serling                          6
# Adolf Hitler                         6
# Joan Rivers                          6
# Marilyn Monroe                       6
# Steven Tyler                         5
# Elton John                           5
# Donald Trump                         5
# Ivanka Trump                         5
# ...

# %%
sketches = pd.read_csv("sketches.csv")
sketches.head()
# Out:
#                             name  skid
# 0                    Church Chat    67
# 1  This Week with David Brinkley    73
# 2                Fox and Friends   260
# 3                    Morning Joe   292
# 4                 Inside The NBA   247

# %%
tenure = pd.read_csv("tenure.csv")
tenure.head(20)
# Out:
#                  aid  n_episodes  eps_present  n_seasons
# 0        Dana Carvey         125          123          7
# 1       Phil Hartman         153          153          8
# 2         Jon Lovitz          91           91          5
# 3   Victoria Jackson         113          113          6
# 4          Jan Hooks          93           93          5
# 5      Dennis Miller         111          111          6
# 6   A. Whitney Brown         101           56          6
# 7          Nora Dunn          91           89          5
# 8       Kevin Nealon         173          172          9
# 9          Tom Davis          56           48          3
# 10      Beck Bennett          97           97          5
# 11     Heidi Gardner          13           13          1
# 12       Alex Moffat          34           32          2
# 13        Chris Redd          13           13          1
# 14     Cecily Strong         118          118          6
# ...

# %%
tenure.eps_present.sort_values(ascending=False).head(10)
# Out:
# 17    295
# 26    267
# 61    251
# 33    219
# 45    192
# 82    181
# 8     172
# 34    162
# 59    159
# 1     153
# Name: eps_present, dtype: int64

# %%
colors = ['lightcoral', 'indianred', 'firebrick', 'maroon']
tenure.eps_present.sort_values(ascending=False).head(10).plot(kind="bar", width=0.9, color=colors)

# %%
hosts = pd.read_csv("hosts.csv")
hosts.head()
# Out:
#                 aid      epid
# 0     Dennis Hopper  19870523
# 1   Natalie Portman  20180203
# 2      Will Ferrell  20180127
# 3  Jessica Chastain  20180120
# 4      Sam Rockwell  20180113

# %%
hosts.aid.value_counts()
# Out:
# Alec Baldwin            17
# Steve Martin            15
# John Goodman            13
# Buck Henry              10
# Tom Hanks                9
# Chevy Chase              8
# Christopher Walken       7
# Danny DeVito             6
# Drew Barrymore           6
# Elliott Gould            6
# Scarlett Johansson       5
# Melissa McCarthy         5
# Ben Affleck              5
# Bill Murray              5
# Justin Timberlake        5
# Tina Fey                 5
# Candice Bergen           5
# Cameron Diaz             4
# Eric Idle                4
# Will Ferrell             4
# Jonah Hill               4
# Lindsay Lohan            4
# Paul Simon               4
# James Franco             4
# Ashton Kutcher           4
# Louis C.K.               4
# Dana Carvey              4
# Michael Palin            4
# Robert DeNiro            3
# Jim Carrey               3
#                         ..
# Gal Gadot                1
# John C. Reilly           1
# Ariana Grande            1
# ...

# %%
colors = ['lightcoral', 'indianred', 'firebrick', 'maroon']
impressions.name.value_counts().head(20).plot(kind="bar", width=0.9, color=colors)
