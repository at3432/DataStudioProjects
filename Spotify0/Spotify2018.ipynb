# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
df = pd.read_csv('top2018.csv')
df.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df = df.drop(columns=['duration_ms', 'time_signature'])
df.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000083     0.552    0.357   77.169
# ...

# %%
df2 = df[['danceability', 'valence', 'name']]
df2.head(10)
# Out:
#    danceability  valence                          name
# 0         0.754    0.357                    God's Plan
# 1         0.740    0.473                          SAD!
# 2         0.587    0.140    rockstar (feat. 21 Savage)
# 3         0.739    0.439  Psycho (feat. Ty Dolla $ign)
# 4         0.835    0.350                In My Feelings
# 5         0.680    0.374                    Better Now
# 6         0.816    0.650                     I Like It
# 7         0.791    0.592      One Kiss (with Dua Lipa)
# 8         0.836    0.510                         IDGAF
# 9         0.626    0.534                       FRIENDS

# %%
pos = df2.sort_values(by='valence').name.tail(20)
pos.sort_values(ascending=False)
# Out:
# 17                                                    X
# 59                                           Sin Pijama
# 25                                         Shape of You
# 12                                        Nice For What
# 18                                            Moonlight
# 22                                                 Mine
# 44                                             Me Niego
# 70    Let Me Go (with Alesso, Florida Georgia Line &...
# 45                                          Jackie Chan
# 51                                              Happier
# 53                    Freaky Friday (feat. Chris Brown)
# 46                      Finesse (Remix) [feat. Cardi B]
# 71                                        Feel It Still
# 94                   Everybody Dies In Their Nightmares
# 41                                                 Dura
# 66              D?jala que vuelva (feat. Manuel Turizo)
# 78                                             Criminal
# ...

# %%
df2.head(20).plot(x='name', y='danceability', kind='barh', legend=None)

# %%
ax = df.sort_values(by='valence').tail(10) \
    .plot(x='name', y='valence', kind='barh', width=0.9, legend=None)

plt.box(False)
plt.tight_layout()
plt.savefig("PositiveSongs.pdf")

# %%
df3 = df.artists.value_counts().sort_values(ascending=False)
df3 = df3.reset_index()
df3.head(10)
# Out:
#              index  artists
# 0      Post Malone        6
# 1     XXXTENTACION        6
# 2            Drake        4
# 3       Marshmello        3
# 4       Ed Sheeran        3
# 5            Ozuna        2
# 6   Camila Cabello        2
# 7   Kendrick Lamar        2
# 8     Selena Gomez        2
# 9  Imagine Dragons        2

# %%
top10 = df.artists.value_counts()
top10.head(10).plot(kind='pie', cmap = 'Oranges', legend=None)

# %%
PostMalone = df[df['artists'] == 'Post Malone']
PostMalone = PostMalone.drop(columns=['id'])
PostMalone
# Out:
#                             name      artists  danceability  energy   key  \
# 2     rockstar (feat. 21 Savage)  Post Malone         0.587   0.535   5.0
# 3   Psycho (feat. Ty Dolla $ign)  Post Malone         0.739   0.559   8.0
# 5                     Better Now  Post Malone         0.680   0.563  10.0
# 32                  I Fall Apart  Post Malone         0.556   0.538   8.0
# 75                   Candy Paint  Post Malone         0.670   0.654   4.0
# 76               Congratulations  Post Malone         0.630   0.804   6.0
#
#     loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 2     -6.090   0.0       0.0898        0.1170          0.000066     0.131
# 3     -8.011   1.0       0.1170        0.5800          0.000000     0.112
# 5     -5.843   1.0       0.0454        0.3540          0.000000     0.136
# 32    -5.408   0.0       0.0382        0.0689          0.000000     0.196
# 75    -5.944   1.0       0.1530        0.6270          0.000001     0.071
# ...

# %%
df4 = df.drop(columns=['artists', 'name', 'id'])
df4.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000083     0.552    0.357   77.169
# 1          0.003720     0.123    0.473   75.023
# 2          0.000066     0.131    0.140  159.847
# 3          0.000000     0.112    0.439  140.124
# 4          0.000060     0.396    0.350   91.030

# %%
# sns.heatmap(PostMalone.corr(),cmap="YlGnBu")

# %%
PostMaloneheat = PostMalone[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
sns.heatmap(PostMaloneheat.corr(),annot=False,cmap="coolwarm")

# %%
PostMaloneheat2 = PostMaloneheat[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
corr = PostMaloneheat2.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,annot=False,cmap="coolwarm")

plt.box(False)
plt.tight_layout()
# plt.savefig("PostMalone.pdf")

# %%
XXXTheat2 = XXXTheat[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
corr = XXXTheat2.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,annot=False,cmap="coolwarm")

plt.box(False)
plt.tight_layout()
# plt.savefig("XXXT.pdf")

# %%
XXXT = df[df['artists'] == 'XXXTENTACION']
XXXT = XXXT.drop(columns=['artists', 'name', 'id', 'instrumentalness', 'mode'])
XXXT
# Out:
#     danceability  energy   key  loudness  speechiness  acousticness  liveness  \
# 1          0.740   0.613   8.0    -4.880       0.1450        0.2580    0.1230
# 18         0.921   0.537   9.0    -5.723       0.0804        0.5560    0.1020
# 28         0.872   0.391   0.0    -9.144       0.2420        0.4690    0.2970
# 38         0.669   0.308  11.0   -10.068       0.0290        0.8830    0.0984
# 62         0.797   0.533   0.0    -9.740       0.0412        0.0172    0.1030
# 94         0.734   0.570   7.0    -7.066       0.1330        0.8470    0.1120
#
#     valence    tempo
# 1     0.473   75.023
# 18    0.711  128.009
# 28    0.437  134.021
# 38    0.520   64.934
# 62    0.329  131.036
# 94    0.689  129.953

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(XXXT.corr(),cmap=cmap)

# %%
sns.heatmap(df.corr(),cmap="Blues")

plt.box(False)
plt.tight_layout()
# plt.savefig("General.pdf")

# %%
sns.set_style(style='ticks')
sns.distplot(df['danceability'],hist=True,kde=True, color='y')

# %%
sns.set_color_codes()
ax = sns.distplot(df['danceability'], color="y")

# %%
sns.distplot(df['energy'], color='y')

# %%
sns.distplot(df['loudness'], color='y')

# %%
ax = sns.kdeplot(df['loudness'], shade=True, color="r", legend=None)

# %%
ax = sns.kdeplot(df['energy'], shade=True, color="g")

# %%
ax = sns.kdeplot(df['valence'], shade=True, color="b")

# %%
ax = sns.kdeplot(df['danceability'], shade=True, color="b")
ax = sns.kdeplot(df['energy'], shade=True, color="g")

plt.box(False)
plt.tight_layout()
# plt.savefig("hist1.pdf")

# %%
ax = sns.kdeplot(df['valence'], shade=True, color="b")
ax = sns.kdeplot(df['energy'], shade=True, color="g")

plt.box(False)
plt.tight_layout()
# plt.savefig("hist2.pdf")

# %%
ax = sns.kdeplot(df['valence'], shade=True, color="b")
ax = sns.kdeplot(df['danceability'], shade=True, color="g")

plt.box(False)
plt.tight_layout()
# plt.savefig("hist3.pdf")

# %%
# g = sns.clustermap(df4, metric="correlation")

# %%
# !pip install plotly
# Out:
# ...
# You are using pip version 9.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import plotly.graph_objects as go

# %%
# fig = go.Figure(data=go.Heatmap(
#                     z=df
# ))
# fig.show()

# %%
df6 = df[['danceability','energy','loudness']]
sns.heatmap(df6.corr(),annot=True,cmap="YlOrRd")

# %%
df7 = df[['energy', 'danceability', 'valence', 'loudness']]
sns.heatmap(df7.corr(),annot=True,cmap="BuPu")

# %%
df8 = df[['acousticness', 'valence', 'instrumentalness', 'tempo', 'key']]
sns.heatmap(df8.corr(),annot=True,cmap="BuPu")
# plt.savefig("testpot.pdf")

# %%
XXXTheat = XXXT[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
sns.heatmap(XXXTheat.corr(),annot=False,cmap="coolwarm")

# %%
XXXTheat2 = XXXTheat[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
corr = XXXTheat2.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,annot=False,cmap="coolwarm")

plt.box(False)
plt.tight_layout()
# plt.savefig("XXXT.pdf")

# %%
df10 = df[['acousticness', 'valence', 'tempo', 'loudness','danceability', 'key', 'energy', 'liveness']]
corr = df10.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr,mask=mask,annot=False,cmap="coolwarm")

# %%
ed = df[df['artists'] == 'Ed Sheeran']
ed = ed.drop(columns=['artists', 'name', 'id', 'instrumentalness', 'mode'])
ed
# Out:
#     danceability  energy  key  loudness  speechiness  acousticness  liveness  \
# 25         0.825   0.652  1.0    -3.183       0.0802         0.581    0.0931
# 29         0.599   0.448  8.0    -6.312       0.0232         0.163    0.1060
# 84         0.587   0.299  8.0    -7.365       0.0263         0.779    0.1230
#
#     valence   tempo
# 25    0.931  95.977
# 29    0.168  95.050
# 84    0.356  94.992

# %%
edheat = ed[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
sns.heatmap(edheat.corr(),annot=False,cmap="coolwarm")

# %%
edheat2 = ed[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
corr = edheat2.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,annot=False,cmap="coolwarm")

plt.box(False)
plt.tight_layout()
# plt.savefig("Ed.pdf")

# %%
drake = df[df['artists'] == 'Drake']
drake = drake.drop(columns=['artists', 'name', 'id', 'instrumentalness', 'mode'])
drake
# Out:
#     danceability  energy  key  loudness  speechiness  acousticness  liveness  \
# 0          0.754   0.449  7.0    -9.211       0.1090        0.0332     0.552
# 4          0.835   0.626  1.0    -5.833       0.1250        0.0589     0.396
# 12         0.586   0.909  8.0    -6.474       0.0705        0.0891     0.119
# 61         0.912   0.412  7.0    -8.074       0.1240        0.0164     0.104
#
#     valence    tempo
# 0     0.357   77.169
# 4     0.350   91.030
# 12    0.757   93.394
# 61    0.422  154.983

# %%
drakeheat = drake[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
sns.heatmap(drakeheat.corr(),annot=False,cmap="coolwarm")

# %%
drakeheat2 = drake[['energy', 'danceability', 'valence', 'loudness', 'acousticness']]
corr = drakeheat2.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,annot=False,cmap="coolwarm")

plt.box(False)
plt.tight_layout()
# plt.savefig("Drake.pdf")

# %%
ax = sns.kdeplot(ed['energy'], shade=True, color="b")
ax = sns.kdeplot(ed['valence'], shade=True, color="g")

plt.box(False)
plt.tight_layout()

# %%
sns.relplot(data=df, x='loudness', y='energy', hue='energy', size='loudness', sizes=(20,500), legend=None)

# %%
sns.relplot(data=df, x='valence', y='loudness', hue='valence', size='loudness', sizes=(20,500), legend=None)
