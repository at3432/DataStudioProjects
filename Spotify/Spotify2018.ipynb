# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
df = pd.read_csv('top2018.csv')
df.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df2 = df[['danceability', 'name']]
df2.head()
# Out:
#    danceability                          name
# 0         0.754                    God's Plan
# 1         0.740                          SAD!
# 2         0.587    rockstar (feat. 21 Savage)
# 3         0.739  Psycho (feat. Ty Dolla $ign)
# 4         0.835                In My Feelings

# %%
df2.head(20).plot(x='name', y='danceability', kind='barh')

# %%
df3 = df.artists.value_counts().sort_values(ascending=False)
df3.reset_index()
# Out:
#                index  artists
# 0        Post Malone        6
# 1       XXXTENTACION        6
# 2              Drake        4
# 3         Ed Sheeran        3
# 4         Marshmello        3
# 5    Imagine Dragons        2
# 6           Dua Lipa        2
# 7     Kendrick Lamar        2
# 8         The Weeknd        2
# 9       Selena Gomez        2
# 10            Khalid        2
# 11             Migos        2
# 12     Ariana Grande        2
# 13     Calvin Harris        2
# 14    Camila Cabello        2
# 15          Maroon 5        2
# 16      Clean Bandit        2
# 17             Ozuna        2
# 18       Sofia Reyes        1
# 19          DJ Snake        1
# 20      Rich The Kid        1
# 21     Natti Natasha        1
# 22        Jonas Blue        1
# 23        Luis Fonsi        1
# 24              ZAYN        1
# 25        Nio Garcia        1
# 26        Rudimental        1
# 27           6ix9ine        1
# 28              Tyga        1
# 29         Lil Dicky        1
# ...

# %%
df3.head(10).plot(kind='pie')

# %%
PostMalone = df[df['artists'] == 'Post Malone']
PostMalone = PostMalone.drop(columns=['id', 'time_signature'])
PostMalone
# Out:
#                             name      artists  danceability  energy   key  \
# 2     rockstar (feat. 21 Savage)  Post Malone         0.587   0.535   5.0
# 3   Psycho (feat. Ty Dolla $ign)  Post Malone         0.739   0.559   8.0
# 5                     Better Now  Post Malone         0.680   0.563  10.0
# 32                  I Fall Apart  Post Malone         0.556   0.538   8.0
# 75                   Candy Paint  Post Malone         0.670   0.654   4.0
# 76               Congratulations  Post Malone         0.630   0.804   6.0
#
#     loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 2     -6.090   0.0       0.0898        0.1170          0.000066     0.131
# 3     -8.011   1.0       0.1170        0.5800          0.000000     0.112
# 5     -5.843   1.0       0.0454        0.3540          0.000000     0.136
# 32    -5.408   0.0       0.0382        0.0689          0.000000     0.196
# 75    -5.944   1.0       0.1530        0.6270          0.000001     0.071
# ...

# %%
df4 = df.drop(columns=['artists', 'name', 'id', 'time_signature'])
df4
# Out:
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0          0.754   0.449   7.0    -9.211   1.0       0.1090      0.033200
# 1          0.740   0.613   8.0    -4.880   1.0       0.1450      0.258000
# 2          0.587   0.535   5.0    -6.090   0.0       0.0898      0.117000
# 3          0.739   0.559   8.0    -8.011   1.0       0.1170      0.580000
# 4          0.835   0.626   1.0    -5.833   1.0       0.1250      0.058900
# 5          0.680   0.563  10.0    -5.843   1.0       0.0454      0.354000
# 6          0.816   0.726   5.0    -3.998   0.0       0.1290      0.099000
# 7          0.791   0.862   9.0    -3.240   0.0       0.1100      0.037000
# 8          0.836   0.544   7.0    -5.975   1.0       0.0943      0.040300
# 9          0.626   0.880   9.0    -2.384   0.0       0.0504      0.205000
# 10         0.765   0.523   2.0    -4.333   1.0       0.0300      0.184000
# 11         0.511   0.566   6.0    -7.230   0.0       0.2000      0.349000
# ...

# %%
sns.heatmap(PostMalone.corr(),cmap="YlGnBu")

# %%
g = sns.clustermap(df4, metric="correlation")
